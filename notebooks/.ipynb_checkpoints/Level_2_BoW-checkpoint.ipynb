# %%
import pandas as pd

# %%
movies = pd.read_csv(r"C:\Users\Varun Bahuguna\OneDrive\Desktop\content-based-recommendation-system\data\movies.csv")

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies.shape
# Out:
# (62423, 3)

# %%
movies.isnull().sum()
# Out:
# movieId    0
# title      0
# genres     0
# dtype: int64

# %%
movies["genres"] = movies["genres"].apply(lambda x:x.replace("|", " "))

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure Animation Children Comedy Fantasy
# 1                   Adventure Children Fantasy
# 2                               Comedy Romance
# 3                         Comedy Drama Romance
# 4                                       Comedy

# %%
movies["genres"] = movies["genres"].str.lower()
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  adventure animation children comedy fantasy
# 1                   adventure children fantasy
# 2                               comedy romance
# 3                         comedy drama romance
# 4                                       comedy

# %%
tags = pd.read_csv(r"C:\Users\Varun Bahuguna\OneDrive\Desktop\content-based-recommendation-system\data\tags.csv")

# %%
tags.head()
# Out:
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455

# %%
tags.shape
# Out:
# (1093360, 4)

# %%
tags.isnull().sum()
# Out:
# userId        0
# movieId       0
# tag          16
# timestamp     0
# dtype: int64

# %%
tags.dropna(subset=["tag"], inplace = True)

# %%
tags.shape
# Out:
# (1093344, 4)

# %%
tags.isnull().sum()
# Out:
# userId       0
# movieId      0
# tag          0
# timestamp    0
# dtype: int64

# %%
tags
# Out:
#          userId  movieId                  tag   timestamp
# 0             3      260              classic  1439472355
# 1             3      260               sci-fi  1439472256
# 2             4     1732          dark comedy  1573943598
# 3             4     1732       great dialogue  1573943604
# 4             4     7569     so bad it's good  1573943455
# ...         ...      ...                  ...         ...
# 1093355  162521    66934  Neil Patrick Harris  1427311611
# 1093356  162521   103341     cornetto trilogy  1427311259
# 1093357  162534   189169               comedy  1527518175
# 1093358  162534   189169             disabled  1527518181
# 1093359  162534   189169              robbery  1527518193
#
# [1093344 rows x 4 columns]

# %%
tags_grouped = tags.groupby("movieId")["tag"].apply(lambda x:" ".join(x)).reset_index()

# %%
tags_grouped
# Out:
#        movieId                                                tag
# 0            1  Owned imdb top 250 Pixar Pixar time travel chi...
# 1            2  Robin Williams time travel fantasy based on ch...
# 2            3  funny best friend duringcreditsstinger fishing...
# 3            4  based on novel or book chick flick divorce int...
# 4            5  aging baby confidence contraception daughter g...
# ...        ...                                                ...
# 45246   208813                                         might like
# 45247   208933                black and white deal with the devil
# 45248   209035  computer animation Japan mass behavior mass sc...
# 45249   209037  chameleon computer animation gluttony humorous...
# 45250   209063  black education friends schools independent sc...
#
# [45251 rows x 2 columns]

# %%
tags_grouped.shape
# Out:
# (45251, 2)

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  adventure animation children comedy fantasy
# 1                   adventure children fantasy
# 2                               comedy romance
# 3                         comedy drama romance
# 4                                       comedy

# %%
tags_grouped.head()
# Out:
#    movieId                                                tag
# 0        1  Owned imdb top 250 Pixar Pixar time travel chi...
# 1        2  Robin Williams time travel fantasy based on ch...
# 2        3  funny best friend duringcreditsstinger fishing...
# 3        4  based on novel or book chick flick divorce int...
# 4        5  aging baby confidence contraception daughter g...

# %%
movies = movies.merge(tags_grouped, on="movieId", how="left")

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres  \
# 0      adventure animation children comedy fantasy
# 1                       adventure children fantasy
# 2                                   comedy romance
# 3                             comedy drama romance
# 4                                           comedy
# ...                                            ...
# 62418                                        drama
# 62419                                  documentary
# 62420                                 comedy drama
# 62421                           (no genres listed)
# 62422                       action adventure drama
#
#                                                      tag
# 0      Owned imdb top 250 Pixar Pixar time travel chi...
# 1      Robin Williams time travel fantasy based on ch...
# 2      funny best friend duringcreditsstinger fishing...
# 3      based on novel or book chick flick divorce int...
# 4      aging baby confidence contraception daughter g...
# ...                                                  ...
# 62418                                                NaN
# 62419                                                NaN
# 62420                                                NaN
# 62421                                                NaN
# 62422                                                NaN
#
# [62423 rows x 4 columns]

# %%
movies["tag"] = movies["tag"].fillna("")

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres  \
# 0      adventure animation children comedy fantasy
# 1                       adventure children fantasy
# 2                                   comedy romance
# 3                             comedy drama romance
# 4                                           comedy
# ...                                            ...
# 62418                                        drama
# 62419                                  documentary
# 62420                                 comedy drama
# 62421                           (no genres listed)
# 62422                       action adventure drama
#
#                                                      tag
# 0      Owned imdb top 250 Pixar Pixar time travel chi...
# 1      Robin Williams time travel fantasy based on ch...
# 2      funny best friend duringcreditsstinger fishing...
# 3      based on novel or book chick flick divorce int...
# 4      aging baby confidence contraception daughter g...
# ...                                                  ...
# 62418
# 62419
# 62420
# 62421
# 62422
#
# [62423 rows x 4 columns]

# %%
movies["bag"] = movies["genres"] + " " + movies["tag"]

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres  \
# 0      adventure animation children comedy fantasy
# 1                       adventure children fantasy
# 2                                   comedy romance
# 3                             comedy drama romance
# 4                                           comedy
# ...                                            ...
# 62418                                        drama
# 62419                                  documentary
# 62420                                 comedy drama
# 62421                           (no genres listed)
# 62422                       action adventure drama
#
#                                                      tag  \
# 0      Owned imdb top 250 Pixar Pixar time travel chi...
# 1      Robin Williams time travel fantasy based on ch...
# 2      funny best friend duringcreditsstinger fishing...
# 3      based on novel or book chick flick divorce int...
# 4      aging baby confidence contraception daughter g...
# ...                                                  ...
# 62418
# 62419
# 62420
# 62421
# 62422
#
#                                                      bag
# 0      adventure animation children comedy fantasy Ow...
# 1      adventure children fantasy Robin Williams time...
# 2      comedy romance funny best friend duringcredits...
# 3      comedy drama romance based on novel or book ch...
# 4      comedy aging baby confidence contraception dau...
# ...                                                  ...
# 62418                                             drama
# 62419                                       documentary
# 62420                                      comedy drama
# 62421                                (no genres listed)
# 62422                            action adventure drama
#
# [62423 rows x 5 columns]

# %%
movies["bag"] = movies["bag"].str.lower()

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres  \
# 0      adventure animation children comedy fantasy
# 1                       adventure children fantasy
# 2                                   comedy romance
# 3                             comedy drama romance
# 4                                           comedy
# ...                                            ...
# 62418                                        drama
# 62419                                  documentary
# 62420                                 comedy drama
# 62421                           (no genres listed)
# 62422                       action adventure drama
#
#                                                      tag  \
# 0      Owned imdb top 250 Pixar Pixar time travel chi...
# 1      Robin Williams time travel fantasy based on ch...
# 2      funny best friend duringcreditsstinger fishing...
# 3      based on novel or book chick flick divorce int...
# 4      aging baby confidence contraception daughter g...
# ...                                                  ...
# 62418
# 62419
# 62420
# 62421
# 62422
#
#                                                      bag
# 0      adventure animation children comedy fantasy ow...
# 1      adventure children fantasy robin williams time...
# 2      comedy romance funny best friend duringcredits...
# 3      comedy drama romance based on novel or book ch...
# 4      comedy aging baby confidence contraception dau...
# ...                                                  ...
# 62418                                             drama
# 62419                                       documentary
# 62420                                      comedy drama
# 62421                                (no genres listed)
# 62422                            action adventure drama
#
# [62423 rows x 5 columns]

# %%
movies.drop(columns=["genres", "tag"], inplace = True)

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                                      bag
# 0      adventure animation children comedy fantasy ow...
# 1      adventure children fantasy robin williams time...
# 2      comedy romance funny best friend duringcredits...
# 3      comedy drama romance based on novel or book ch...
# 4      comedy aging baby confidence contraception dau...
# ...                                                  ...
# 62418                                             drama
# 62419                                       documentary
# 62420                                      comedy drama
# 62421                                (no genres listed)
# 62422                            action adventure drama
#
# [62423 rows x 3 columns]

# %%
movies.isnull().sum()
# Out:
# movieId    0
# title      0
# bag        0
# dtype: int64

# %%
movies.shape
# Out:
# (62423, 3)

# %%
movies.reset_index(drop=True, inplace=True)

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                                      bag
# 0      adventure animation children comedy fantasy ow...
# 1      adventure children fantasy robin williams time...
# 2      comedy romance funny best friend duringcredits...
# 3      comedy drama romance based on novel or book ch...
# 4      comedy aging baby confidence contraception dau...
# ...                                                  ...
# 62418                                             drama
# 62419                                       documentary
# 62420                                      comedy drama
# 62421                                (no genres listed)
# 62422                            action adventure drama
#
# [62423 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(max_features=5000, stop_words="english")

# %%
vectors = cv.fit_transform(movies["bag"])

# %%
vectors.shape
# Out:
# (62423, 5000)

# %%
cv.get_feature_names_out()[:1000]
# Out:
# array(['007', '01', '02', '03', '04', '05', '06', '07', '08', '09', '10',
#        '100', '11', '12', '13', '16th', '17', '17th', '18th', '1900s',
#        '1910s', '1920', '1920s', '1930s', '1940s', '1950s', '1960',
#        '1960s', '1970', '1970s', '1980', '1980s', '1990s', '1999', '19th',
#        '20', '2000s', '2001', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019', '2020', '20th', '250', '2d', '30', '300', '35',
#        '3d', '4th', '50', '50s', '51', '55', '60s', '70', '70mm', '70s',
#        '80', '80s', '90s', '_moodwishlist', 'a24', 'aardman', 'aaron',
#        'abandoned', 'abandonment', 'abba', 'abduction', 'abigail',
#        'abilities', 'abortion', 'abraham', 'abrams', 'abroad', 'abrupt',
#        'absorbing', 'abstract', 'absurd', 'absurdism', 'absurdist',
#        'abuse', 'abusive', 'academy', 'accent', 'accents', 'acceptance',
#        'accident', 'accusation', 'accused', 'act', 'acted', 'acting',
#        'action', 'activism', 'activist', 'actor', 'actors', 'actress',
#        'actresses', 'actual', 'actually', 'adam', 'adams', 'adaptation',
#        'adapted', 'adaption', 'added', 'addict', 'addiction',
#        'adolescence', 'adolf', 'adoption', 'adrenaline', 'adrien',
#        'adult', 'adultery', 'adults', 'adventure', 'adventurous',
#        'adversity', 'advertising', 'aerial', 'aesthetic', 'affair',
#        'affairs', 'affectionate', 'affleck', 'afghanistan', 'afi',
#        'africa', 'african', 'aftercreditsstinger', 'afterlife', 'agatha',
#        'age', 'agency', 'agent', 'agents', 'ages', 'aging', 'ai', 'aids',
#        'air', 'aircraft', 'aires', 'airplane', 'airport', 'aki', 'akira',
#        'al', 'alabama', 'alain', 'alan', 'alaska', 'alba', 'albert',
#        'alcatraz', 'alcohol', 'alcoholic', 'alcoholism', 'alec',
#        'alejandro', 'alex', 'alexander', 'alexandre', 'alfonso', 'alfred',
#        'ali', 'alice', 'alicia', 'alien', 'alienation', 'aliens',
#        'alison', 'alive', 'allan', 'allegorical', 'allegory', 'allen',
#        'allison', 'almodovar', 'alps', 'alter', 'alternate',
#        'alternative', 'altman', 'alzheimer', 'amanda', 'amateur',
#        'amazing', 'amazon', 'ambient', 'ambiguity', 'ambiguous',
#        'ambition', 'ambitious', 'ambulance', 'ambush', 'america',
#        'american', 'americana', 'americans', 'amish', 'amnesia', 'amoral',
#        'amusement', 'amy', 'anamorphic', 'anarchic', 'anarchy', 'ancient',
#        'anders', 'anderson', 'andrei', 'andrew', 'andrews', 'android',
#        'androids', 'andy', 'ang', 'angel', 'angela', 'angeles',
#        'angelina', 'angels', 'anger', 'angry', 'angst', 'animal',
#        'animals', 'animated', 'animation', 'anime', 'aniston', 'anjelica',
#        'ann', 'anna', 'anne', 'annemari', 'annoying', 'antagonist',
#        'antarctica', 'anthology', 'anthony', 'anthropomorphic',
#        'anthropomorphism', 'anti', 'antichrist', 'antihero', 'anton',
#        'antonio', 'ants', 'anxiety', 'apache', 'apartheid', 'apartment',
#        'apatow', 'apes', 'apocalypse', 'apocalyptic', 'appealing',
#        'apple', 'apprentice', 'arab', 'arcade', 'archaeologist',
#        'archaeology', 'archeology', 'archery', 'architect',
#        'architecture', 'archive', 'arctic', 'area', 'argentina',
#        'argento', 'aristocracy', 'aristocrat', 'arizona', 'arkin', 'arm',
#        'armie', 'arms', 'armstrong', 'army', 'arnold', 'aronofsky',
#        'arquette', 'arranged', 'arrest', 'arrow', 'arson', 'art',
#        'arterton', 'arthouse', 'arthur', 'arthurian', 'artificial',
#        'artist', 'artistic', 'artists', 'arts', 'artsy', 'artwork',
#        'asghar', 'ashley', 'ashton', 'asia', 'asian', 'asimov', 'askew',
#        'asperger', 'aspiring', 'ass', 'assassin', 'assassination',
#        'assassins', 'assault', 'astaire', 'asteroid', 'astronaut',
#        'astronauts', 'astronomy', 'asylum', 'atheism', 'athlete',
#        'atkinson', 'atlanta', 'atlantis', 'atmosphere', 'atmospheric',
#        'atomic', 'attack', 'attacks', 'attempt', 'attempted',
#        'attenborough', 'attention', 'attorney', 'attract', 'attraction',
#        'aubrey', 'audience', 'audition', 'audrey', 'aunt', 'austen',
#        'austere', 'australia', 'australian', 'austria', 'authentic',
#        'authenticity', 'author', 'authoritarian', 'autism',
#        'autobiographical', 'autobiography', 'automobile', 'autopsy',
#        'available', 'avant', 'avengers', 'average', 'avi', 'aviation',
#        'avorrida', 'awakening', 'award', 'aware', 'away', 'awe',
#        'awesome', 'awful', 'awkward', 'awry', 'ax', 'aykroyd', 'baby',
#        'babysitter', 'bachelor', 'bacon', 'bad', 'badass', 'bag', 'bait',
#        'baker', 'baldwin', 'bale', 'ball', 'ballet', 'balloon',
#        'baltimore', 'bana', 'band', 'banderas', 'bandit', 'bangkok',
#        'bank', 'banking', 'banks', 'banned', 'bar', 'barbara', 'barbie',
#        'barcelona', 'bardem', 'barker', 'baron', 'barrier', 'barry',
#        'barrymore', 'bartender', 'baruchel', 'base', 'baseball', 'based',
#        'basement', 'basil', 'basinger', 'basketball', 'bat', 'bateman',
#        'bates', 'bath', 'bathtub', 'batman', 'battle', 'battles',
#        'baumbach', 'bay', 'baz', 'bb', 'bbc', 'bd', 'bdsm', 'beach',
#        'bean', 'bear', 'bears', 'beast', 'beat', 'beating', 'beatles',
#        'beautiful', 'beautifully', 'beauty', 'bechdel', 'beckinsale',
#        'bed', 'bee', 'beer', 'beginning', 'behavior', 'bela', 'belgium',
#        'believable', 'bell', 'bellucci', 'belt', 'belushi', 'ben',
#        'bending', 'benedict', 'benicio', 'benigni', 'bergman', 'berlin',
#        'bernard', 'berry', 'besson', 'best', 'betamax', 'betrayal',
#        'bettany', 'bette', 'better', 'betty', 'bfi', 'bgab', 'bible',
#        'biblical', 'bibliothek', 'bicycle', 'biel', 'big', 'bigfoot',
#        'bike', 'biker', 'bikini', 'billionaire', 'billy', 'binks',
#        'binoche', 'biographical', 'biography', 'biological', 'biology',
#        'biopic', 'bird', 'birds', 'birth', 'birthday', 'bisexual',
#        'bisexuality', 'bit', 'bite', 'biting', 'bitter', 'bittersweet',
#        'bizarre', 'black', 'blackmail', 'blade', 'blair', 'blake',
#        'blanchett', 'bland', 'blasphemous', 'blaxploitation', 'bleak',
#        'blind', 'blindfold', 'blindness', 'block', 'blomkamp', 'blonde',
#        'blood', 'bloody', 'bloom', 'blow', 'blu', 'blue', 'blues',
#        'blunt', 'board', 'boarding', 'boat', 'bob', 'body', 'bodyguard',
#        'bogart', 'bollywood', 'bomb', 'bomber', 'bombing', 'bombs',
#        'bond', 'bondage', 'bonding', 'bonds', 'bong', 'bonham', 'boobs',
#        'book', 'books', 'bookshop', 'boot', 'booth', 'border',
#        'borderline', 'boring', 'boris', 'boss', 'boston', 'bounty', 'bow',
#        'bowery', 'bowie', 'bowling', 'box', 'boxer', 'boxing', 'boy',
#        'boyega', 'boyfriend', 'boyle', 'boys', 'br', 'brad', 'bradley',
#        'braff', 'brain', 'brainwashing', 'branagh', 'brand', 'brando',
#        'brat', 'bravery', 'brawl', 'brazil', 'brazilian', 'break',
#        'breakdown', 'breaking', 'breakthroughs', 'breast', 'breathtaking',
#        'brendan', 'breslin', 'brett', 'brian', 'bride', 'bridge',
#        'bridges', 'brie', 'brief', 'bright', 'brilliant', 'brit',
#        'britain', 'british', 'brittany', 'broadway', 'broderick', 'brody',
#        'broken', 'brolin', 'bromance', 'bromantic', 'bronson', 'brooklyn',
#        'brooks', 'bros', 'brosnan', 'brothel', 'brother', 'brotherhood',
#        'brothers', 'brown', 'browning', 'bruce', 'bruno', 'brutal',
#        'brutality', 'bryan', 'bryce', 'btaege', 'buddhism', 'buddhist',
#        'buddies', 'buddy', 'budget', 'buenos', 'bug', 'bugs', 'build',
#        'building', 'bullet', 'bullock', 'bullshit', 'bully', 'bullying',
#        'bunker', 'bunny', 'bureaucracy', 'burgess', 'burglar', 'burglary',
#        'buried', 'burn', 'burning', 'burroughs', 'burt', 'burton', 'bus',
#        'buscemi', 'bush', 'business', 'buster', 'butcher', 'butler',
#        'butt', 'butterfly', 'buy', 'byrne', 'caan', 'cabin', 'cable',
#        'cage', 'cagney', 'caine', 'california', 'calm', 'cam', 'cambodia',
#        'cameo', 'cameos', 'camera', 'camerawork', 'cameron', 'camp',
#        'campaign', 'campbell', 'camping', 'campy', 'canada', 'canadian',
#        'cancer', 'candy', 'cannabis', 'cannes', 'cannibal', 'cannibalism',
#        'cannibals', 'canuxploitation', 'caper', 'capitalism', 'capote',
#        'capra', 'captain', 'captivating', 'captive', 'capture', 'car',
#        'card', 'care', 'career', 'carell', 'carey', 'caribbean', 'carl',
#        'carlos', 'carnival', 'carol', 'carolina', 'carpenter', 'carrey',
#        'carrie', 'carroll', 'cars', 'cartel', 'carter', 'cartoon',
#        'cartoonish', 'cary', 'case', 'casey', 'cash', 'casino', 'cassel',
#        'cast', 'casting', 'castle', 'castration', 'cat', 'catastrophe',
#        'catchy', 'cate', 'cathartic', 'catherine', 'catholic',
#        'catholicism', 'cats', 'cattle', 'cav', 'cavalry', 'cave',
#        'cavemen', 'cavill', 'celebration', 'celebrity', 'cell',
#        'cemetery', 'censorship', 'center', 'central', 'century', 'cera',
#        'cerebral', 'cg', 'cgi', 'chainsaw', 'champion', 'chan', 'chance',
#        'change', 'changing', 'channel', 'channing', 'chaos', 'chaplin',
#        'character', 'characterization', 'characters', 'charles',
#        'charlie', 'charlize', 'charlotte', 'charlton', 'charming',
#        'chase', 'chastain', 'chazelle', 'cheadle', 'cheap', 'cheating',
#        'cheek', 'cheerleader', 'cheerleading', 'cheers', 'cheese',
#        'cheesy', 'chef', 'chemistry', 'chess', 'chevy', 'chicago',
#        'chick', 'chicken', 'chief', 'child', 'childhood', 'childish',
#        'children', 'chile', 'chimpanzee', 'china', 'chinese', 'chloe',
#        'chloë', 'cho', 'chocolate', 'choices', 'choir', 'choreographic',
#        'choreography', 'chosen', 'chow', 'chris', 'christ', 'christensen',
#        'christian', 'christianity', 'christie', 'christina', 'christmas',
#        'christoph', 'christopher', 'chuck', 'church', 'cia', 'cigarette',
#        'cillian', 'cinderella', 'cinema', 'cinematic', 'cinematographer',
#        'cinematography', 'cinéma', 'circus', 'city', 'civil',
#        'civilization', 'claire', 'clancy', 'clark', 'clarke', 'clash',
#        'class', 'classic', 'classical', 'classics', 'classroom', 'claude',
#        'claus', 'claustrophobic', 'claymation', 'clea', 'clean', 'cleese',
#        'clement', 'clever', 'cliche', 'cliched', 'cliches', 'cliché',
#        'cliff', 'cliffhanger', 'climate', 'climbing', 'clint', 'clive',
#        'clock', 'clone', 'clones', 'cloning', 'clooney', 'close',
#        'closet', 'clown', 'clowns', 'club', 'clv', 'coach', 'coal',
#        'coast', 'cocaine', 'code', 'coen', 'coffee', 'coffin', 'cohen',
#        'coincidences', 'cold', 'cole', 'colin', 'collar', 'collection',
#        'collector', 'college', 'collette', 'collins', 'colombia',
#        'colonial', 'colonialism', 'colony', 'color', 'colorado',
#        'colorful', 'colors', 'colourful', 'colours', 'columbus', 'com',
#        'coma', 'combat', 'comedian', 'comedic', 'comedies', 'comedy',
#        'comes', 'comet', 'comic', 'comical', 'comics', 'coming',
#        'commando', 'commentary', 'commercial', 'commune', 'communication',
#        'communism', 'communist', 'community', 'company', 'compare',
#        'compassion', 'compassionate', 'compelling', 'competition',
#        'complex', 'complicated', 'composer', 'compulsive', 'computer',
#        'computers', 'conan', 'concentration', 'concept', 'concert',
#        'condition', 'confession', 'confidence', 'confined', 'conflict',
#        'conformity', 'confrontational', 'confused', 'confusing',
#        'confusion', 'congress', 'connelly', 'connery', 'conrad', 'cons',
#        'conscience', 'consciousness', 'conspiracy', 'constructed',
#        'construction', 'consumerism', 'contact', 'contemplative',
#        'content', 'contest', 'contract'], dtype=object)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
def recommend(movie_name):
    movie_name = movie_name.lower()
    
    matches = movies[movies["title"].str.lower().str.contains(movie_name)]
    
    if matches.empty:
        print("Movie not found 😅")
        return
    
    idx = matches.index[0]
    
    # 🔥 KEY LINE (on-the-fly similarity)
    dist = cosine_similarity(vectors[idx], vectors).flatten()
    
    scores = sorted(list(enumerate(dist)), reverse = True, key = lambda x : x[1])[1:6]

    rec = []
    # top 5
    for i in scores:
        rec.append(movies.iloc[i[0]].title)

    return rec

# %%
recommend("shawshank")
# Out:
# ['Year of the Tiger, The (Año del tigre, El) (2011)',
#  'Seven (a.k.a. Se7en) (1995)',
#  'Lucky Number Slevin (2006)',
#  'Escapist, The (2008)',
#  'Sixth Sense, The (1999)']

# %%
recommend("fight club")
# Out:
# ['Primal Fear (1996)',
#  'Seven (a.k.a. Se7en) (1995)',
#  'The Machinist (2004)',
#  'Shutter Island (2010)',
#  'Donnie Darko (2001)']

# %%
recommend("toy story")
# Out:
# ['Toy Story 2 (1999)',
#  "Bug's Life, A (1998)",
#  'Monsters, Inc. (2001)',
#  'The Adventures of André and Wally B. (1984)',
#  'Toy Story 3 (2010)']
