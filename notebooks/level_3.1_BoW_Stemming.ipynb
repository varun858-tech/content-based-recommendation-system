# %%
import pandas as pd

# %%
movies = pd.read_csv(r"C:\Users\Varun Bahuguna\OneDrive\Desktop\content-based-recommendation-system\data\movies.csv")

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies.shape
# Out:
# (62423, 3)

# %%
movies.isnull().sum()
# Out:
# movieId    0
# title      0
# genres     0
# dtype: int64

# %%
movies["genres"] = movies["genres"].apply(lambda x:x.replace("|", " "))

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure Animation Children Comedy Fantasy
# 1                   Adventure Children Fantasy
# 2                               Comedy Romance
# 3                         Comedy Drama Romance
# 4                                       Comedy

# %%
movies["genres"] = movies["genres"].str.lower()
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  adventure animation children comedy fantasy
# 1                   adventure children fantasy
# 2                               comedy romance
# 3                         comedy drama romance
# 4                                       comedy

# %%
tags = pd.read_csv(r"C:\Users\Varun Bahuguna\OneDrive\Desktop\content-based-recommendation-system\data\tags.csv")

# %%
tags.head()
# Out:
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455

# %%
tags.shape
# Out:
# (1093360, 4)

# %%
tags.isnull().sum()
# Out:
# userId        0
# movieId       0
# tag          16
# timestamp     0
# dtype: int64

# %%
tags.dropna(subset=["tag"], inplace = True)

# %%
tags.shape
# Out:
# (1093344, 4)

# %%
tags.isnull().sum()
# Out:
# userId       0
# movieId      0
# tag          0
# timestamp    0
# dtype: int64

# %%
tags
# Out:
#          userId  movieId                  tag   timestamp
# 0             3      260              classic  1439472355
# 1             3      260               sci-fi  1439472256
# 2             4     1732          dark comedy  1573943598
# 3             4     1732       great dialogue  1573943604
# 4             4     7569     so bad it's good  1573943455
# ...         ...      ...                  ...         ...
# 1093355  162521    66934  Neil Patrick Harris  1427311611
# 1093356  162521   103341     cornetto trilogy  1427311259
# 1093357  162534   189169               comedy  1527518175
# 1093358  162534   189169             disabled  1527518181
# 1093359  162534   189169              robbery  1527518193
#
# [1093344 rows x 4 columns]

# %%
tags_grouped = tags.groupby("movieId")["tag"].apply(lambda x:" ".join(x)).reset_index()

# %%
tags_grouped
# Out:
#        movieId                                                tag
# 0            1  Owned imdb top 250 Pixar Pixar time travel chi...
# 1            2  Robin Williams time travel fantasy based on ch...
# 2            3  funny best friend duringcreditsstinger fishing...
# 3            4  based on novel or book chick flick divorce int...
# 4            5  aging baby confidence contraception daughter g...
# ...        ...                                                ...
# 45246   208813                                         might like
# 45247   208933                black and white deal with the devil
# 45248   209035  computer animation Japan mass behavior mass sc...
# 45249   209037  chameleon computer animation gluttony humorous...
# 45250   209063  black education friends schools independent sc...
#
# [45251 rows x 2 columns]

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  adventure animation children comedy fantasy
# 1                   adventure children fantasy
# 2                               comedy romance
# 3                         comedy drama romance
# 4                                       comedy

# %%
tags_grouped.head()
# Out:
#    movieId                                                tag
# 0        1  Owned imdb top 250 Pixar Pixar time travel chi...
# 1        2  Robin Williams time travel fantasy based on ch...
# 2        3  funny best friend duringcreditsstinger fishing...
# 3        4  based on novel or book chick flick divorce int...
# 4        5  aging baby confidence contraception daughter g...

# %%
movies = movies.merge(tags_grouped, on="movieId", how="left")

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres  \
# 0      adventure animation children comedy fantasy
# 1                       adventure children fantasy
# 2                                   comedy romance
# 3                             comedy drama romance
# 4                                           comedy
# ...                                            ...
# 62418                                        drama
# 62419                                  documentary
# 62420                                 comedy drama
# 62421                           (no genres listed)
# 62422                       action adventure drama
#
#                                                      tag
# 0      Owned imdb top 250 Pixar Pixar time travel chi...
# 1      Robin Williams time travel fantasy based on ch...
# 2      funny best friend duringcreditsstinger fishing...
# 3      based on novel or book chick flick divorce int...
# 4      aging baby confidence contraception daughter g...
# ...                                                  ...
# 62418                                                NaN
# 62419                                                NaN
# 62420                                                NaN
# 62421                                                NaN
# 62422                                                NaN
#
# [62423 rows x 4 columns]

# %%
movies["tag"] = movies["tag"].fillna("")

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres  \
# 0      adventure animation children comedy fantasy
# 1                       adventure children fantasy
# 2                                   comedy romance
# 3                             comedy drama romance
# 4                                           comedy
# ...                                            ...
# 62418                                        drama
# 62419                                  documentary
# 62420                                 comedy drama
# 62421                           (no genres listed)
# 62422                       action adventure drama
#
#                                                      tag
# 0      Owned imdb top 250 Pixar Pixar time travel chi...
# 1      Robin Williams time travel fantasy based on ch...
# 2      funny best friend duringcreditsstinger fishing...
# 3      based on novel or book chick flick divorce int...
# 4      aging baby confidence contraception daughter g...
# ...                                                  ...
# 62418
# 62419
# 62420
# 62421
# 62422
#
# [62423 rows x 4 columns]

# %%
movies["bag"] = movies["genres"] + " " + movies["tag"]

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres  \
# 0      adventure animation children comedy fantasy
# 1                       adventure children fantasy
# 2                                   comedy romance
# 3                             comedy drama romance
# 4                                           comedy
# ...                                            ...
# 62418                                        drama
# 62419                                  documentary
# 62420                                 comedy drama
# 62421                           (no genres listed)
# 62422                       action adventure drama
#
#                                                      tag  \
# 0      Owned imdb top 250 Pixar Pixar time travel chi...
# 1      Robin Williams time travel fantasy based on ch...
# 2      funny best friend duringcreditsstinger fishing...
# 3      based on novel or book chick flick divorce int...
# 4      aging baby confidence contraception daughter g...
# ...                                                  ...
# 62418
# 62419
# 62420
# 62421
# 62422
#
#                                                      bag
# 0      adventure animation children comedy fantasy Ow...
# 1      adventure children fantasy Robin Williams time...
# 2      comedy romance funny best friend duringcredits...
# 3      comedy drama romance based on novel or book ch...
# 4      comedy aging baby confidence contraception dau...
# ...                                                  ...
# 62418                                             drama
# 62419                                       documentary
# 62420                                      comedy drama
# 62421                                (no genres listed)
# 62422                            action adventure drama
#
# [62423 rows x 5 columns]

# %%
movies["bag"] = movies["bag"].str.lower()

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres  \
# 0      adventure animation children comedy fantasy
# 1                       adventure children fantasy
# 2                                   comedy romance
# 3                             comedy drama romance
# 4                                           comedy
# ...                                            ...
# 62418                                        drama
# 62419                                  documentary
# 62420                                 comedy drama
# 62421                           (no genres listed)
# 62422                       action adventure drama
#
#                                                      tag  \
# 0      Owned imdb top 250 Pixar Pixar time travel chi...
# 1      Robin Williams time travel fantasy based on ch...
# 2      funny best friend duringcreditsstinger fishing...
# 3      based on novel or book chick flick divorce int...
# 4      aging baby confidence contraception daughter g...
# ...                                                  ...
# 62418
# 62419
# 62420
# 62421
# 62422
#
#                                                      bag
# 0      adventure animation children comedy fantasy ow...
# 1      adventure children fantasy robin williams time...
# 2      comedy romance funny best friend duringcredits...
# 3      comedy drama romance based on novel or book ch...
# 4      comedy aging baby confidence contraception dau...
# ...                                                  ...
# 62418                                             drama
# 62419                                       documentary
# 62420                                      comedy drama
# 62421                                (no genres listed)
# 62422                            action adventure drama
#
# [62423 rows x 5 columns]

# %%
movies.drop(columns=["genres", "tag"], inplace = True)

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                                      bag
# 0      adventure animation children comedy fantasy ow...
# 1      adventure children fantasy robin williams time...
# 2      comedy romance funny best friend duringcredits...
# 3      comedy drama romance based on novel or book ch...
# 4      comedy aging baby confidence contraception dau...
# ...                                                  ...
# 62418                                             drama
# 62419                                       documentary
# 62420                                      comedy drama
# 62421                                (no genres listed)
# 62422                            action adventure drama
#
# [62423 rows x 3 columns]

# %%
movies.isnull().sum()
# Out:
# movieId    0
# title      0
# bag        0
# dtype: int64

# %%
movies.shape
# Out:
# (62423, 3)

# %%
movies.reset_index(drop=True, inplace=True)

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                                      bag
# 0      adventure animation children comedy fantasy ow...
# 1      adventure children fantasy robin williams time...
# 2      comedy romance funny best friend duringcredits...
# 3      comedy drama romance based on novel or book ch...
# 4      comedy aging baby confidence contraception dau...
# ...                                                  ...
# 62418                                             drama
# 62419                                       documentary
# 62420                                      comedy drama
# 62421                                (no genres listed)
# 62422                            action adventure drama
#
# [62423 rows x 3 columns]

# %%
import nltk
from nltk.stem.porter import PorterStemmer

ps = PorterStemmer()

# %%
def stem(txt):
    words = txt.split()

    stemmed_list = []

    for word in words:
        stemmed_list.append(ps.stem(word))

    return " ".join(stemmed_list)

# %%
movies["bag"] = movies["bag"].apply(stem)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(max_features=5000, stop_words="english")

# %%
vectors = cv.fit_transform(movies["bag"])

# %%
vectors.shape
# Out:
# (62423, 5000)

# %%
cv.get_feature_names_out()[:1000]
# Out:
# array(['007', '01', '02', '03', '04', '05', '06', '07', '08', '09', '10',
#        '100', '11', '12', '13', '15', '16th', '17', '17th', '18th',
#        '1900', '1910', '1920', '1930', '1940', '1950', '1960', '1970',
#        '1980', '1990', '1995', '1999', '19th', '20', '2000', '2001',
#        '2002', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020', '20th', '21st', '250', '2d', '30', '300', '35', '3d',
#        '4th', '50', '51', '55', '60', '70', '70mm', '80', '90',
#        '_moodwishlist', 'a24', 'aardman', 'aaron', 'abandon', 'abba',
#        'abduct', 'abigail', 'abil', 'aborigin', 'abort', 'abraham',
#        'abram', 'abroad', 'abrupt', 'absent', 'absolut', 'absorb',
#        'abstract', 'absurd', 'absurdist', 'abus', 'academi', 'academia',
#        'accent', 'accept', 'accid', 'accident', 'account', 'accus', 'act',
#        'action', 'activ', 'activist', 'actor', 'actress', 'actual', 'ad',
#        'adam', 'adapt', 'addict', 'addit', 'adolesc', 'adolf', 'adopt',
#        'adrenalin', 'adrien', 'adult', 'adulteri', 'adventur', 'advers',
#        'advertis', 'aerial', 'aesthet', 'affair', 'affect', 'affection',
#        'affleck', 'afghanistan', 'afi', 'africa', 'african',
#        'aftercreditssting', 'afterlif', 'ag', 'agatha', 'age', 'agenc',
#        'agent', 'aggress', 'agricultur', 'ai', 'aid', 'air', 'aircraft',
#        'airplan', 'airport', 'aki', 'akira', 'al', 'alabama', 'alain',
#        'alan', 'alaska', 'alba', 'albert', 'alcatraz', 'alcohol', 'alec',
#        'alejandro', 'alex', 'alexand', 'alexandr', 'alfonso', 'alfr',
#        'ali', 'alic', 'alicia', 'alien', 'alison', 'aliv', 'allan',
#        'allegor', 'allegori', 'allen', 'allig', 'allison', 'almodovar',
#        'alon', 'alp', 'alter', 'altern', 'altman', 'alway', 'alzheimer',
#        'amanda', 'amateur', 'amaz', 'amazon', 'ambient', 'ambigu',
#        'ambit', 'ambiti', 'ambul', 'ambush', 'america', 'american',
#        'americana', 'ami', 'amish', 'amnesia', 'amor', 'amsterdam',
#        'amus', 'ana', 'anamorph', 'anarch', 'anarchi', 'anarchist',
#        'ancient', 'ander', 'anderson', 'andi', 'andr', 'andrea', 'andrei',
#        'andrew', 'android', 'andrzej', 'ang', 'angel', 'angela',
#        'angelina', 'anger', 'angri', 'angst', 'anim', 'animal', 'aniston',
#        'anjelica', 'ann', 'anna', 'annemari', 'annett', 'annoy', 'anonym',
#        'anoth', 'ant', 'antagonist', 'antarctica', 'antholog', 'anthoni',
#        'anthropolog', 'anthropomorph', 'anti', 'antichrist', 'antihero',
#        'anton', 'antonio', 'anxieti', 'apach', 'apart', 'apartheid',
#        'apatow', 'ape', 'apocalyps', 'apocalypt', 'apollo', 'appeal',
#        'appl', 'apprentic', 'arab', 'arabia', 'arabian', 'arcad',
#        'archaeolog', 'archaeologist', 'archeolog', 'archeri', 'architect',
#        'architectur', 'archiv', 'arctic', 'area', 'argentina', 'argento',
#        'aristocraci', 'aristocrat', 'arizona', 'arkin', 'arm', 'armi',
#        'armor', 'armstrong', 'arnold', 'aronofski', 'arquett', 'arrang',
#        'arrest', 'arrow', 'arson', 'art', 'arterton', 'arthous', 'arthur',
#        'arthurian', 'artifici', 'artist', 'artsi', 'artwork', 'asghar',
#        'ashley', 'ashton', 'asia', 'asian', 'asimov', 'askew', 'aspir',
#        'ass', 'assassin', 'assault', 'assist', 'astair', 'asteroid',
#        'astronaut', 'astronomi', 'asylum', 'atheism', 'athlet',
#        'atkinson', 'atlanta', 'atlanti', 'atmospher', 'atom', 'attach',
#        'attack', 'attempt', 'attenborough', 'attent', 'attorney',
#        'attract', 'aubrey', 'audienc', 'audit', 'audrey', 'aunt',
#        'austen', 'auster', 'austin', 'australia', 'australian', 'austria',
#        'authent', 'author', 'authoritarian', 'autism', 'autobiograph',
#        'autobiographi', 'automobil', 'autopsi', 'autumn', 'avail',
#        'avant', 'aveng', 'averag', 'avi', 'aviat', 'avorrida', 'aw',
#        'awaken', 'awar', 'award', 'away', 'awe', 'awesom', 'awkward',
#        'awri', 'ax', 'aykroyd', 'bab', 'babi', 'babysitt', 'bacal',
#        'bachelor', 'background', 'bacon', 'bad', 'badass', 'bag', 'bait',
#        'bake', 'baker', 'bald', 'baldwin', 'bale', 'ball', 'ballet',
#        'balloon', 'ballroom', 'baltimor', 'ban', 'bana', 'band',
#        'bandera', 'bandit', 'bangkok', 'bank', 'bar', 'barbara', 'barber',
#        'barbi', 'barcelona', 'bardem', 'bare', 'barker', 'barn', 'baron',
#        'barri', 'barrier', 'barrymor', 'bartend', 'baruchel', 'base',
#        'basebal', 'basement', 'bash', 'basil', 'basing', 'basketbal',
#        'basqu', 'bassett', 'bat', 'bate', 'bateman', 'bath', 'bathtub',
#        'batman', 'battl', 'battlefield', 'baumbach', 'bay', 'baz', 'bb',
#        'bbc', 'bd', 'bdsm', 'beach', 'bean', 'bear', 'beast', 'beat',
#        'beatl', 'beatti', 'beauti', 'bechdel', 'beckinsal', 'becom',
#        'bed', 'bee', 'beer', 'befor', 'begin', 'behavior', 'bela',
#        'belgium', 'believ', 'bell', 'bellucci', 'belt', 'belushi', 'ben',
#        'bend', 'bene', 'benedict', 'benicio', 'benigni', 'bennett',
#        'bergman', 'berlin', 'bernal', 'bernard', 'bernardo', 'berri',
#        'bertolucci', 'besson', 'best', 'bet', 'betamax', 'betray', 'bett',
#        'bettani', 'better', 'betti', 'beverli', 'bfi', 'bgab', 'bias',
#        'bibl', 'biblic', 'bibliothek', 'bicycl', 'biel', 'big', 'bigelow',
#        'bigfoot', 'bike', 'biker', 'bikini', 'billi', 'billionair',
#        'bink', 'binoch', 'biograph', 'biographi', 'biolog', 'biologist',
#        'biopic', 'birch', 'bird', 'birth', 'birthday', 'bisexu', 'bit',
#        'bite', 'bitter', 'bittersweet', 'bizarr', 'bizzar', 'black',
#        'blackmail', 'blade', 'blair', 'blake', 'blanchett', 'bland',
#        'blasphem', 'blaxploit', 'bleak', 'blind', 'blindfold', 'block',
#        'blogger', 'blomkamp', 'blond', 'blood', 'bloodi', 'bloom', 'blow',
#        'blowup', 'blu', 'blue', 'blunt', 'bo', 'board', 'boat', 'bob',
#        'bodi', 'body', 'bodybuild', 'bodyguard', 'bogart', 'bollywood',
#        'bomb', 'bomber', 'bond', 'bondag', 'bong', 'bonham', 'boob',
#        'boobi', 'book', 'bookshop', 'boon', 'boot', 'booth', 'border',
#        'borderlin', 'bore', 'bori', 'boring', 'boss', 'boston', 'bounti',
#        'bow', 'boweri', 'bowi', 'bowl', 'box', 'boxer', 'boy', 'boyega',
#        'boyfriend', 'boyl', 'boys', 'br', 'brad', 'bradley', 'braff',
#        'brain', 'brainwash', 'branagh', 'brand', 'brando', 'brat',
#        'braveri', 'brawl', 'brazil', 'brazilian', 'break', 'breakdown',
#        'breakthrough', 'breakup', 'breast', 'breathtak', 'brendan',
#        'breslin', 'brett', 'brian', 'bride', 'bridg', 'brie', 'brief',
#        'bright', 'brilliant', 'brit', 'britain', 'british', 'brittani',
#        'bro', 'broadway', 'broderick', 'brodi', 'broken', 'brolin',
#        'bromanc', 'bromant', 'bronson', 'brook', 'brooklyn', 'brosnan',
#        'broth', 'brothel', 'brother', 'brotherhood', 'brown', 'bruce',
#        'bruno', 'brutal', 'bryan', 'bryce', 'btaeg', 'bu', 'budapest',
#        'buddhism', 'buddhist', 'buddi', 'budget', 'bueno', 'buffalo',
#        'bug', 'build', 'bull', 'bullet', 'bullfight', 'bulli', 'bullock',
#        'bullshit', 'bunker', 'bunni', 'bureaucraci', 'burgess', 'burglar',
#        'burglari', 'buri', 'burn', 'burrough', 'burt', 'burton',
#        'buscemi', 'bush', 'busi', 'buster', 'butcher', 'butler', 'butt',
#        'butterfli', 'buy', 'buñuel', 'byrn', 'byron', 'caan', 'cabaret',
#        'cabin', 'cabl', 'cage', 'cagney', 'cain', 'california', 'calm',
#        'cam', 'cambodia', 'cameo', 'camera', 'camerawork', 'cameron',
#        'camp', 'campaign', 'campbel', 'campi', 'canada', 'canadian',
#        'cancer', 'candi', 'cann', 'cannabi', 'cannib', 'canuxploit',
#        'caper', 'capit', 'capitalist', 'capot', 'capra', 'captain',
#        'captiv', 'captur', 'car', 'card', 'care', 'career', 'carel',
#        'carey', 'cari', 'caribbean', 'carl', 'carlo', 'carniv', 'carol',
#        'carolina', 'carpent', 'carr', 'carrey', 'carri', 'carrie',
#        'carrol', 'cartel', 'carter', 'cartoon', 'cartoonish', 'case',
#        'casey', 'cash', 'casino', 'cassavet', 'cassel', 'cast', 'castl',
#        'castrat', 'cat', 'catastroph', 'catchi', 'cate', 'cathart',
#        'catherin', 'cathol', 'catholic', 'cattl', 'cav', 'cavalri',
#        'cave', 'cavemen', 'cavil', 'celebr', 'cell', 'cello', 'celtic',
#        'cemeteri', 'censorship', 'center', 'central', 'centuri', 'cera',
#        'cerebr', 'cg', 'cgi', 'chain', 'chainsaw', 'chair', 'chalamet',
#        'challeng', 'chamber', 'champion', 'chan', 'chanc', 'chaney',
#        'chang', 'channel', 'chao', 'chaplin', 'charact', 'character',
#        'charl', 'charli', 'charliz', 'charlott', 'charlton', 'charm',
#        'chase', 'chastain', 'chazel', 'che', 'cheadl', 'cheap', 'cheat',
#        'cheek', 'cheerlead', 'cheers', 'chees', 'cheesi', 'chef',
#        'chemistri', 'chess', 'chevi', 'chicago', 'chick', 'chicken',
#        'chief', 'child', 'childbirth', 'childhood', 'childish',
#        'children', 'chile', 'chimpanze', 'china', 'chines', 'chiwetel',
#        'chloe', 'chloë', 'cho', 'chocol', 'choic', 'choir', 'choreograph',
#        'choreographi', 'chosen', 'chow', 'chri', 'christ', 'christensen',
#        'christi', 'christian', 'christina', 'christma', 'christoph',
#        'chuck', 'chun', 'church', 'cia', 'cigarett', 'cillian',
#        'cinderella', 'cinema', 'cinemat', 'cinematographer',
#        'cinematographi', 'cinematography', 'cinéma', 'circu', 'citi',
#        'citizen', 'civil', 'clair', 'clanci', 'clark', 'clash', 'class',
#        'classic', 'classism', 'classroom', 'clau', 'claud',
#        'claustrophob', 'clay', 'claymat', 'clea', 'clean', 'cleef',
#        'clees', 'clement', 'clerk', 'clever', 'clich', 'clichã', 'cliché',
#        'cliff', 'cliffhang', 'climat', 'climb', 'clint', 'cliqu', 'clive',
#        'clock', 'clockwork', 'clone', 'clooney', 'close', 'closet',
#        'cloth', 'clown', 'club', 'clumsi', 'clv', 'coach', 'coal',
#        'coast', 'cocain', 'cod', 'code', 'coen', 'coffe', 'coffin',
#        'cohen', 'coincid', 'cold', 'cole', 'colin', 'collar', 'collect',
#        'collector', 'colleg', 'collett', 'collin', 'colombia', 'coloni',
#        'color', 'colorado', 'colour', 'columbu', 'com', 'coma', 'combat',
#        'come', 'comeback', 'comed', 'comedi', 'comedian', 'comedy',
#        'comet', 'comic', 'coming', 'command', 'commando', 'commentari',
#        'commerci', 'commit', 'common', 'commun', 'communist', 'compani',
#        'compare', 'compass', 'compassion', 'compel', 'competit',
#        'complex', 'complic', 'compos', 'compuls', 'comput', 'conan',
#        'concentr', 'concept', 'concert', 'condit', 'confess', 'confid',
#        'confin', 'conflict', 'conform', 'confront', 'confus', 'congress',
#        'connect', 'connecticut', 'connelli', 'conneri', 'connolli',
#        'conrad', 'conscienc', 'conscious', 'conserv', 'conspiraci',
#        'construct', 'consumer', 'contact', 'contempl', 'content',
#        'contest', 'continu', 'contract', 'contriv', 'control',
#        'controversi', 'conveni', 'convent', 'convers', 'convict',
#        'convolut', 'coogan', 'cook'], dtype=object)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
def recommend(movie_name):
    movie_name = movie_name.lower()
    
    matches = movies[movies["title"].str.lower().str.contains(movie_name)]
    
    if matches.empty:
        print("Movie not found 😅")
        return
    
    idx = matches.index[0]
    
    # 🔥 KEY LINE (on-the-fly similarity)
    dist = cosine_similarity(vectors[idx], vectors).flatten()
    
    scores = sorted(list(enumerate(dist)), reverse = True, key = lambda x : x[1])[1:6]

    rec = []
    # top 5
    for i in scores:
        rec.append(movies.iloc[i[0]].title)

    return rec

# %%
recommend("shawshank")
# Out:
# ['Year of the Tiger, The (Año del tigre, El) (2011)',
#  'Seven (a.k.a. Se7en) (1995)',
#  'Lucky Number Slevin (2006)',
#  'Escapist, The (2008)',
#  'Sixth Sense, The (1999)']

# %%
recommend("fight club")
# Out:
# ['Shutter Island (2010)',
#  'Primal Fear (1996)',
#  'Seven (a.k.a. Se7en) (1995)',
#  'Uninvited, The (2009)',
#  'The Machinist (2004)']

# %%
recommend("toy story")
# Out:
# ['Toy Story 2 (1999)',
#  "Bug's Life, A (1998)",
#  'Finding Nemo (2003)',
#  'Monsters, Inc. (2001)',
#  'Ice Age (2002)']
